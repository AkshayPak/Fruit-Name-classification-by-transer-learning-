# %%
# General Libs
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
#from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Akshay P\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Akshay P\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\Akshay P\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
im_shape = (299,299)

TRAINING_DIR = 'ds_frutas_am/train'
TEST_DIR = 'ds_frutas_am/test'

seed = 10

BATCH_SIZE = 16

# %%
data_generator = ImageDataGenerator(
        validation_split=0.2,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        preprocessing_function=preprocess_input,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')
val_data_generator = ImageDataGenerator(preprocessing_function=preprocess_input,validation_split=0.2)

# %%
train_generator = data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=True, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="training")
# Generator para parte validação
validation_generator = val_data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="validation")

# Generator para dataset de teste
test_generator = ImageDataGenerator(preprocessing_function=preprocess_input)
test_generator = test_generator.flow_from_directory(TEST_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE)

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
nb_test_samples = test_generator.samples
classes = list(train_generator.class_indices.keys())
print('Classes: '+str(classes))
num_classes  = len(classes)
# Out:
# Found 72 images belonging to 6 classes.
# Found 18 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.
# Classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %%
plt.figure(figsize=(15,15))
for i in range(9):
    #gera subfigures
    plt.subplot(330 + 1 + i)
    batch = (train_generator.next()[0]+1)/2*255
    image = batch[0].astype('uint8')
    plt.imshow(image)
plt.show()

# %% [markdown]
# # Transfer Learning from a Deep Model

# %%
base_model = InceptionResNetV2(weights='imagenet',include_top=False, input_shape=(im_shape[0], im_shape[1], 3))

x = base_model.output
x = Flatten()(x)
x = Dense(100, activation='relu')(x)
predictions = Dense(num_classes, activation='softmax', kernel_initializer='random_uniform')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Freezing pretrained layers
base_model.trainable = False

optimizer = Adam()
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
epochs = 200

# Saving the best model
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='model.h5',
        monitor='val_loss', save_best_only=True, verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,verbose=1)
]

history = model.fit(
        train_generator,
        steps_per_epoch=nb_train_samples // BATCH_SIZE,
        epochs=epochs,
        callbacks = callbacks_list,
        validation_data=validation_generator,
        verbose = 1,
        validation_steps=nb_validation_samples // BATCH_SIZE)
# Out:
# Epoch 1/200
# 4/4 [==============================] - ETA: 0s - loss: 8.6681 - accuracy: 0.1250
# Epoch 1: val_loss improved from inf to 4.69014, saving model to model.h5
# 4/4 [==============================] - 62s 12s/step - loss: 8.6681 - accuracy: 0.1250 - val_loss: 4.6901 - val_accuracy: 0.4375
# Epoch 2/200
# 4/4 [==============================] - ETA: 0s - loss: 5.2636 - accuracy: 0.4643
# Epoch 2: val_loss improved from 4.69014 to 2.78772, saving model to model.h5
# 4/4 [==============================] - 33s 9s/step - loss: 5.2636 - accuracy: 0.4643 - val_loss: 2.7877 - val_accuracy: 0.4375
# Epoch 3/200
# 4/4 [==============================] - ETA: 0s - loss: 2.1383 - accuracy: 0.4844
# Epoch 3: val_loss improved from 2.78772 to 0.95065, saving model to model.h5
# 4/4 [==============================] - 36s 10s/step - loss: 2.1383 - accuracy: 0.4844 - val_loss: 0.9507 - val_accuracy: 0.6875
# Epoch 4/200
# 4/4 [==============================] - ETA: 0s - loss: 0.7312 - accuracy: 0.7500
# Epoch 4: val_loss improved from 0.95065 to 0.66094, saving model to model.h5
# 4/4 [==============================] - 34s 9s/step - loss: 0.7312 - accuracy: 0.7500 - val_loss: 0.6609 - val_accuracy: 0.7500
# Epoch 5/200
# 4/4 [==============================] - ETA: 0s - loss: 0.6786 - accuracy: 0.7143
# Epoch 5: val_loss improved from 0.66094 to 0.65331, saving model to model.h5
# 4/4 [==============================] - 34s 9s/step - loss: 0.6786 - accuracy: 0.7143 - val_loss: 0.6533 - val_accuracy: 0.8125
# Epoch 6/200
# 4/4 [==============================] - ETA: 0s - loss: 0.4387 - accuracy: 0.8571
# Epoch 6: val_loss improved from 0.65331 to 0.36401, saving model to model.h5
# 4/4 [==============================] - 33s 10s/step - loss: 0.4387 - accuracy: 0.8571 - val_loss: 0.3640 - val_accuracy: 0.8750
# Epoch 7/200
# 4/4 [==============================] - ETA: 0s - loss: 0.3425 - accuracy: 0.8571
# Epoch 7: val_loss did not improve from 0.36401
# 4/4 [==============================] - 28s 8s/step - loss: 0.3425 - accuracy: 0.8571 - val_loss: 0.3798 - val_accuracy: 0.6875
# Epoch 8/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2980 - accuracy: 0.9107
# Epoch 8: val_loss did not improve from 0.36401
# 4/4 [==============================] - 28s 7s/step - loss: 0.2980 - accuracy: 0.9107 - val_loss: 0.3702 - val_accuracy: 0.8125
# Epoch 9/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1873 - accuracy: 0.9219
# Epoch 9: val_loss did not improve from 0.36401
# 4/4 [==============================] - 32s 8s/step - loss: 0.1873 - accuracy: 0.9219 - val_loss: 0.5811 - val_accuracy: 0.7500
# Epoch 10/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.8929
# Epoch 10: val_loss did not improve from 0.36401
# 4/4 [==============================] - 29s 7s/step - loss: 0.2490 - accuracy: 0.8929 - val_loss: 0.4497 - val_accuracy: 0.7500
# Epoch 11/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1166 - accuracy: 0.9643
# Epoch 11: val_loss improved from 0.36401 to 0.28394, saving model to model.h5
# 4/4 [==============================] - 38s 10s/step - loss: 0.1166 - accuracy: 0.9643 - val_loss: 0.2839 - val_accuracy: 0.9375
# Epoch 12/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1691 - accuracy: 0.9531
# Epoch 12: val_loss did not improve from 0.28394
# 4/4 [==============================] - 32s 8s/step - loss: 0.1691 - accuracy: 0.9531 - val_loss: 0.3895 - val_accuracy: 0.8750
# Epoch 13/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 0.9821
# Epoch 13: val_loss did not improve from 0.28394
# 4/4 [==============================] - 28s 8s/step - loss: 0.1232 - accuracy: 0.9821 - val_loss: 0.3757 - val_accuracy: 0.8125
# Epoch 14/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9821
# Epoch 14: val_loss did not improve from 0.28394
# 4/4 [==============================] - 30s 8s/step - loss: 0.1159 - accuracy: 0.9821 - val_loss: 0.2956 - val_accuracy: 0.9375
# Epoch 15/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 0.9464
# Epoch 15: val_loss improved from 0.28394 to 0.27983, saving model to model.h5
# 4/4 [==============================] - 35s 9s/step - loss: 0.1368 - accuracy: 0.9464 - val_loss: 0.2798 - val_accuracy: 0.9375
# Epoch 16/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9643
# Epoch 16: val_loss improved from 0.27983 to 0.27981, saving model to model.h5
# 4/4 [==============================] - 34s 9s/step - loss: 0.1103 - accuracy: 0.9643 - val_loss: 0.2798 - val_accuracy: 0.9375
# Epoch 17/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9643
# Epoch 17: val_loss did not improve from 0.27981
# 4/4 [==============================] - 28s 7s/step - loss: 0.0891 - accuracy: 0.9643 - val_loss: 0.3025 - val_accuracy: 0.8750
# Epoch 18/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9643
# Epoch 18: val_loss improved from 0.27981 to 0.20863, saving model to model.h5
# 4/4 [==============================] - 35s 10s/step - loss: 0.1219 - accuracy: 0.9643 - val_loss: 0.2086 - val_accuracy: 0.9375
# Epoch 19/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.20863
# 4/4 [==============================] - 32s 8s/step - loss: 0.0474 - accuracy: 1.0000 - val_loss: 0.4719 - val_accuracy: 0.8125
# Epoch 20/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9464
# Epoch 20: val_loss did not improve from 0.20863
# 4/4 [==============================] - 28s 8s/step - loss: 0.0886 - accuracy: 0.9464 - val_loss: 0.4021 - val_accuracy: 0.8125
# Epoch 21/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9821
# Epoch 21: val_loss did not improve from 0.20863
# 4/4 [==============================] - 29s 8s/step - loss: 0.0820 - accuracy: 0.9821 - val_loss: 0.4634 - val_accuracy: 0.8125
# Epoch 22/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9643
# Epoch 22: val_loss did not improve from 0.20863
# 4/4 [==============================] - 28s 7s/step - loss: 0.0727 - accuracy: 0.9643 - val_loss: 0.4173 - val_accuracy: 0.8750
# Epoch 23/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.9821
# Epoch 23: val_loss did not improve from 0.20863
# 4/4 [==============================] - 28s 7s/step - loss: 0.0893 - accuracy: 0.9821 - val_loss: 0.5239 - val_accuracy: 0.6875
# Epoch 24/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9643
# Epoch 24: val_loss did not improve from 0.20863
# 4/4 [==============================] - 28s 7s/step - loss: 0.0769 - accuracy: 0.9643 - val_loss: 0.6229 - val_accuracy: 0.7500
# Epoch 25/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9821
# Epoch 25: val_loss did not improve from 0.20863
# 4/4 [==============================] - 28s 7s/step - loss: 0.0391 - accuracy: 0.9821 - val_loss: 0.6725 - val_accuracy: 0.8125
# Epoch 26/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1899 - accuracy: 0.9464
# Epoch 26: val_loss did not improve from 0.20863
# 4/4 [==============================] - 28s 7s/step - loss: 0.1899 - accuracy: 0.9464 - val_loss: 0.2370 - val_accuracy: 0.8750
# Epoch 27/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9821
# Epoch 27: val_loss did not improve from 0.20863
# 4/4 [==============================] - 29s 8s/step - loss: 0.0567 - accuracy: 0.9821 - val_loss: 0.4163 - val_accuracy: 0.7500
# Epoch 28/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.9375
# Epoch 28: val_loss did not improve from 0.20863
# 4/4 [==============================] - 33s 8s/step - loss: 0.1536 - accuracy: 0.9375 - val_loss: 0.2548 - val_accuracy: 0.8125
# Epoch 29/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.9844
# Epoch 29: val_loss did not improve from 0.20863
# 4/4 [==============================] - 31s 8s/step - loss: 0.0866 - accuracy: 0.9844 - val_loss: 0.2996 - val_accuracy: 0.8125
# Epoch 30/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.20863
# 4/4 [==============================] - 30s 8s/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.6269 - val_accuracy: 0.6250
# Epoch 31/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9643
# Epoch 31: val_loss did not improve from 0.20863
# 4/4 [==============================] - 29s 7s/step - loss: 0.0589 - accuracy: 0.9643 - val_loss: 0.7259 - val_accuracy: 0.7500
# Epoch 32/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9688
# Epoch 32: val_loss did not improve from 0.20863
# 4/4 [==============================] - 33s 9s/step - loss: 0.0512 - accuracy: 0.9688 - val_loss: 0.4988 - val_accuracy: 0.7500
# Epoch 33/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9688
# Epoch 33: val_loss did not improve from 0.20863
# 4/4 [==============================] - 32s 8s/step - loss: 0.0506 - accuracy: 0.9688 - val_loss: 0.2628 - val_accuracy: 0.9375
# Epoch 34/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 1.0000
# Epoch 34: val_loss did not improve from 0.20863
# 4/4 [==============================] - 34s 9s/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.2791 - val_accuracy: 0.8125
# Epoch 35/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9821
# Epoch 35: val_loss did not improve from 0.20863
# 4/4 [==============================] - 29s 8s/step - loss: 0.0313 - accuracy: 0.9821 - val_loss: 0.4088 - val_accuracy: 0.8125
# Epoch 36/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 1.0000
# Epoch 36: val_loss did not improve from 0.20863
# 4/4 [==============================] - 30s 7s/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.2402 - val_accuracy: 0.9375
# Epoch 37/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9643
# Epoch 37: val_loss did not improve from 0.20863
# 4/4 [==============================] - 31s 8s/step - loss: 0.0931 - accuracy: 0.9643 - val_loss: 0.2328 - val_accuracy: 0.8750
# Epoch 38/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9643
# Epoch 38: val_loss did not improve from 0.20863
# 4/4 [==============================] - 32s 8s/step - loss: 0.0738 - accuracy: 0.9643 - val_loss: 0.5315 - val_accuracy: 0.8125
# Epoch 39/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 1.0000
# Epoch 39: val_loss did not improve from 0.20863
# 4/4 [==============================] - 30s 7s/step - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.3855 - val_accuracy: 0.7500
# Epoch 40/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9821
# Epoch 40: val_loss did not improve from 0.20863
# 4/4 [==============================] - 28s 8s/step - loss: 0.0227 - accuracy: 0.9821 - val_loss: 0.2224 - val_accuracy: 0.8750
# Epoch 41/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.20863
# 4/4 [==============================] - 28s 7s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2327 - val_accuracy: 0.9375
# Epoch 42/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0566 - accuracy: 0.9821
# Epoch 42: val_loss improved from 0.20863 to 0.19188, saving model to model.h5
# 4/4 [==============================] - 37s 10s/step - loss: 0.0566 - accuracy: 0.9821 - val_loss: 0.1919 - val_accuracy: 0.9375
# Epoch 43/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 1.0000
# Epoch 43: val_loss improved from 0.19188 to 0.18199, saving model to model.h5
# 4/4 [==============================] - 36s 10s/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.1820 - val_accuracy: 0.8750
# Epoch 44/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.18199
# 4/4 [==============================] - 32s 8s/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.8750
# Epoch 45/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.18199
# 4/4 [==============================] - 31s 8s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.8750
# Epoch 46/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9844
# Epoch 46: val_loss did not improve from 0.18199
# 4/4 [==============================] - 34s 9s/step - loss: 0.0242 - accuracy: 0.9844 - val_loss: 0.2083 - val_accuracy: 0.9375
# Epoch 47/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9821
# Epoch 47: val_loss did not improve from 0.18199
# 4/4 [==============================] - 30s 8s/step - loss: 0.0617 - accuracy: 0.9821 - val_loss: 0.2053 - val_accuracy: 0.9375
# Epoch 48/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.18199
# 4/4 [==============================] - 31s 9s/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.4310 - val_accuracy: 0.8125
# Epoch 49/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9844
# Epoch 49: val_loss did not improve from 0.18199
# 4/4 [==============================] - 35s 9s/step - loss: 0.0292 - accuracy: 0.9844 - val_loss: 0.2638 - val_accuracy: 0.9375
# Epoch 50/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 50: val_loss did not improve from 0.18199
# 4/4 [==============================] - 31s 8s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.3009 - val_accuracy: 0.9375
# Epoch 51/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 1.0000
# Epoch 51: val_loss did not improve from 0.18199
# 4/4 [==============================] - 32s 8s/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.2621 - val_accuracy: 0.9375
# Epoch 52/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.9643
# Epoch 52: val_loss did not improve from 0.18199
# 4/4 [==============================] - 31s 8s/step - loss: 0.1140 - accuracy: 0.9643 - val_loss: 0.3757 - val_accuracy: 0.8125
# Epoch 53/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9643
# Epoch 53: val_loss did not improve from 0.18199
# 4/4 [==============================] - 30s 8s/step - loss: 0.1237 - accuracy: 0.9643 - val_loss: 0.2216 - val_accuracy: 0.8750
# Epoch 54/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9688
# Epoch 54: val_loss did not improve from 0.18199
# 4/4 [==============================] - 33s 9s/step - loss: 0.0374 - accuracy: 0.9688 - val_loss: 0.2038 - val_accuracy: 0.9375
# Epoch 55/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9821
# Epoch 55: val_loss improved from 0.18199 to 0.17630, saving model to model.h5
# 4/4 [==============================] - 38s 10s/step - loss: 0.0298 - accuracy: 0.9821 - val_loss: 0.1763 - val_accuracy: 0.9375
# Epoch 56/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 56: val_loss did not improve from 0.17630
# 4/4 [==============================] - 32s 8s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2442 - val_accuracy: 0.8750
# Epoch 57/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 57: val_loss did not improve from 0.17630
# 4/4 [==============================] - 30s 8s/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.2682 - val_accuracy: 0.9375
# Epoch 58/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 58: val_loss did not improve from 0.17630
# 4/4 [==============================] - 32s 8s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.2698 - val_accuracy: 0.9375
# Epoch 59/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 59: val_loss did not improve from 0.17630
# 4/4 [==============================] - 31s 9s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.3513 - val_accuracy: 0.9375
# Epoch 60/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9821
# Epoch 60: val_loss did not improve from 0.17630
# 4/4 [==============================] - 30s 9s/step - loss: 0.0253 - accuracy: 0.9821 - val_loss: 0.2978 - val_accuracy: 0.8750
# Epoch 61/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 1.0000
# Epoch 61: val_loss did not improve from 0.17630
# 4/4 [==============================] - 31s 8s/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.2452 - val_accuracy: 0.8750
# Epoch 62/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9821
# Epoch 62: val_loss improved from 0.17630 to 0.14934, saving model to model.h5
# 4/4 [==============================] - 34s 9s/step - loss: 0.0194 - accuracy: 0.9821 - val_loss: 0.1493 - val_accuracy: 0.8750
# Epoch 63/200
# 4/4 [==============================] - ETA: 0s - loss: 8.0340e-04 - accuracy: 1.0000
# Epoch 63: val_loss improved from 0.14934 to 0.14241, saving model to model.h5
# 4/4 [==============================] - 25s 7s/step - loss: 8.0340e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 1.0000
# Epoch 64/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 64: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.8750
# Epoch 65/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1322 - accuracy: 0.9643
# Epoch 65: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.1322 - accuracy: 0.9643 - val_loss: 0.3044 - val_accuracy: 0.8125
# Epoch 66/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 66: val_loss did not improve from 0.14241
# 4/4 [==============================] - 21s 6s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5796 - val_accuracy: 0.7500
# Epoch 67/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 1.0000
# Epoch 67: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 6s/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.2758 - val_accuracy: 0.9375
# Epoch 68/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 1.0000
# Epoch 68: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.3574 - val_accuracy: 0.9375
# Epoch 69/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 69: val_loss did not improve from 0.14241
# 4/4 [==============================] - 23s 6s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.3749 - val_accuracy: 0.8750
# Epoch 70/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9821
# Epoch 70: val_loss did not improve from 0.14241
# 4/4 [==============================] - 24s 7s/step - loss: 0.1093 - accuracy: 0.9821 - val_loss: 0.3718 - val_accuracy: 0.8750
# Epoch 71/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 71: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4397 - val_accuracy: 0.8125
# Epoch 72/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5908 - val_accuracy: 0.7500
# Epoch 73/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9821
# Epoch 73: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.0398 - accuracy: 0.9821 - val_loss: 0.4483 - val_accuracy: 0.8125
# Epoch 74/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 74: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.3732 - val_accuracy: 0.8125
# Epoch 75/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9821
# Epoch 75: val_loss did not improve from 0.14241
# 4/4 [==============================] - 19s 5s/step - loss: 0.0227 - accuracy: 0.9821 - val_loss: 0.3549 - val_accuracy: 0.9375
# Epoch 76/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 76: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.3681 - val_accuracy: 0.9375
# Epoch 77/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9821
# Epoch 77: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.0400 - accuracy: 0.9821 - val_loss: 0.2885 - val_accuracy: 0.9375
# Epoch 78/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 78: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.8750
# Epoch 79/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 79: val_loss did not improve from 0.14241
# 4/4 [==============================] - 19s 5s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.3007 - val_accuracy: 0.8750
# Epoch 80/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 1.0000
# Epoch 80: val_loss did not improve from 0.14241
# 4/4 [==============================] - 24s 6s/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.1814 - val_accuracy: 0.9375
# Epoch 81/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9821
# Epoch 81: val_loss did not improve from 0.14241
# 4/4 [==============================] - 23s 6s/step - loss: 0.0526 - accuracy: 0.9821 - val_loss: 0.1500 - val_accuracy: 0.9375
# Epoch 82/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9844
# Epoch 82: val_loss did not improve from 0.14241
# 4/4 [==============================] - 24s 6s/step - loss: 0.0196 - accuracy: 0.9844 - val_loss: 0.2437 - val_accuracy: 0.9375
# Epoch 83/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 83: val_loss did not improve from 0.14241
# 4/4 [==============================] - 21s 6s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9375
# Epoch 84/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 84: val_loss did not improve from 0.14241
# 4/4 [==============================] - 21s 6s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9375
# Epoch 85/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 85: val_loss did not improve from 0.14241
# 4/4 [==============================] - 21s 5s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2608 - val_accuracy: 0.8750
# Epoch 86/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.14241
# 4/4 [==============================] - 20s 5s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.4391 - val_accuracy: 0.8750
# Epoch 87/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9821
# Epoch 87: val_loss did not improve from 0.14241
# 4/4 [==============================] - 21s 6s/step - loss: 0.0371 - accuracy: 0.9821 - val_loss: 0.2935 - val_accuracy: 0.8125
# Epoch 88/200
# 4/4 [==============================] - ETA: 0s - loss: 6.9352e-04 - accuracy: 1.0000
# Epoch 88: val_loss did not improve from 0.14241
# 4/4 [==============================] - 21s 5s/step - loss: 6.9352e-04 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9375
# Epoch 89/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9821
# Epoch 89: val_loss did not improve from 0.14241
# 4/4 [==============================] - 25s 6s/step - loss: 0.0378 - accuracy: 0.9821 - val_loss: 0.2343 - val_accuracy: 0.9375
# Epoch 90/200
# 4/4 [==============================] - ETA: 0s - loss: 4.9439e-04 - accuracy: 1.0000
# Epoch 90: val_loss did not improve from 0.14241
# 4/4 [==============================] - 23s 6s/step - loss: 4.9439e-04 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.8750
# Epoch 91/200
# 4/4 [==============================] - ETA: 0s - loss: 6.7947e-04 - accuracy: 1.0000
# Epoch 91: val_loss did not improve from 0.14241
# 4/4 [==============================] - 23s 7s/step - loss: 6.7947e-04 - accuracy: 1.0000 - val_loss: 0.2555 - val_accuracy: 0.9375
# Epoch 92/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 92: val_loss did not improve from 0.14241
# 4/4 [==============================] - 23s 6s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2900 - val_accuracy: 0.9375
# Epoch 93/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9821
# Epoch 93: val_loss did not improve from 0.14241
# 4/4 [==============================] - 21s 5s/step - loss: 0.0537 - accuracy: 0.9821 - val_loss: 0.1572 - val_accuracy: 0.8750
# Epoch 94/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 94: val_loss did not improve from 0.14241
# 4/4 [==============================] - 23s 6s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.1743 - val_accuracy: 0.9375
# Epoch 95/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9821
# Epoch 95: val_loss improved from 0.14241 to 0.13719, saving model to model.h5
# 4/4 [==============================] - 27s 7s/step - loss: 0.2109 - accuracy: 0.9821 - val_loss: 0.1372 - val_accuracy: 0.9375
# Epoch 96/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 96: val_loss did not improve from 0.13719
# 4/4 [==============================] - 24s 6s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.9375
# Epoch 97/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9821
# Epoch 97: val_loss did not improve from 0.13719
# 4/4 [==============================] - 28s 7s/step - loss: 0.0542 - accuracy: 0.9821 - val_loss: 0.2320 - val_accuracy: 0.9375
# Epoch 98/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 98: val_loss did not improve from 0.13719
# 4/4 [==============================] - 24s 7s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 0.9375
# Epoch 99/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9821
# Epoch 99: val_loss did not improve from 0.13719
# 4/4 [==============================] - 24s 6s/step - loss: 0.0341 - accuracy: 0.9821 - val_loss: 0.1992 - val_accuracy: 0.8750
# Epoch 100/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9643
# Epoch 100: val_loss did not improve from 0.13719
# 4/4 [==============================] - 23s 6s/step - loss: 0.0746 - accuracy: 0.9643 - val_loss: 0.2642 - val_accuracy: 0.9375
# Epoch 101/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9821
# Epoch 101: val_loss did not improve from 0.13719
# 4/4 [==============================] - 23s 6s/step - loss: 0.0210 - accuracy: 0.9821 - val_loss: 0.4836 - val_accuracy: 0.8750
# Epoch 102/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9844
# Epoch 102: val_loss did not improve from 0.13719
# 4/4 [==============================] - 25s 7s/step - loss: 0.0462 - accuracy: 0.9844 - val_loss: 0.2662 - val_accuracy: 0.8125
# Epoch 103/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9821
# Epoch 103: val_loss did not improve from 0.13719
# 4/4 [==============================] - 22s 6s/step - loss: 0.0431 - accuracy: 0.9821 - val_loss: 0.2517 - val_accuracy: 0.9375
# Epoch 104/200
# 4/4 [==============================] - ETA: 0s - loss: 9.5087e-04 - accuracy: 1.0000
# Epoch 104: val_loss did not improve from 0.13719
# 4/4 [==============================] - 26s 7s/step - loss: 9.5087e-04 - accuracy: 1.0000 - val_loss: 0.3013 - val_accuracy: 0.8125
# Epoch 105/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 105: val_loss did not improve from 0.13719
# 4/4 [==============================] - 22s 6s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.3879 - val_accuracy: 0.7500
# Epoch 106/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 106: val_loss did not improve from 0.13719
# 4/4 [==============================] - 23s 7s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4539 - val_accuracy: 0.8125
# Epoch 107/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9821
# Epoch 107: val_loss did not improve from 0.13719
# 4/4 [==============================] - 24s 6s/step - loss: 0.0198 - accuracy: 0.9821 - val_loss: 0.3624 - val_accuracy: 0.7500
# Epoch 108/200
# 4/4 [==============================] - ETA: 0s - loss: 8.9017e-04 - accuracy: 1.0000
# Epoch 108: val_loss did not improve from 0.13719
# 4/4 [==============================] - 25s 6s/step - loss: 8.9017e-04 - accuracy: 1.0000 - val_loss: 0.2946 - val_accuracy: 0.8750
# Epoch 109/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9821
# Epoch 109: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 5s/step - loss: 0.0228 - accuracy: 0.9821 - val_loss: 0.3132 - val_accuracy: 0.7500
# Epoch 110/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 110: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 5s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4111 - val_accuracy: 0.8125
# Epoch 111/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 111: val_loss did not improve from 0.13719
# 4/4 [==============================] - 22s 5s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4168 - val_accuracy: 0.7500
# Epoch 112/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 112: val_loss did not improve from 0.13719
# 4/4 [==============================] - 19s 6s/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.3638 - val_accuracy: 0.7500
# Epoch 113/200
# 4/4 [==============================] - ETA: 0s - loss: 5.5289e-04 - accuracy: 1.0000
# Epoch 113: val_loss did not improve from 0.13719
# 4/4 [==============================] - 19s 5s/step - loss: 5.5289e-04 - accuracy: 1.0000 - val_loss: 0.3007 - val_accuracy: 0.8750
# Epoch 114/200
# 4/4 [==============================] - ETA: 0s - loss: 5.7058e-04 - accuracy: 1.0000
# Epoch 114: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 5s/step - loss: 5.7058e-04 - accuracy: 1.0000 - val_loss: 0.3155 - val_accuracy: 0.9375
# Epoch 115/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9821
# Epoch 115: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.0655 - accuracy: 0.9821 - val_loss: 0.3059 - val_accuracy: 0.9375
# Epoch 116/200
# 4/4 [==============================] - ETA: 0s - loss: 4.6780e-04 - accuracy: 1.0000
# Epoch 116: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 5s/step - loss: 4.6780e-04 - accuracy: 1.0000 - val_loss: 0.4049 - val_accuracy: 0.7500
# Epoch 117/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 117: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5288 - val_accuracy: 0.8125
# Epoch 118/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9821
# Epoch 118: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.0383 - accuracy: 0.9821 - val_loss: 0.3081 - val_accuracy: 0.8750
# Epoch 119/200
# 4/4 [==============================] - ETA: 0s - loss: 3.6062e-04 - accuracy: 1.0000
# Epoch 119: val_loss did not improve from 0.13719
# 4/4 [==============================] - 23s 6s/step - loss: 3.6062e-04 - accuracy: 1.0000 - val_loss: 0.3225 - val_accuracy: 0.9375
# Epoch 120/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 120: val_loss did not improve from 0.13719
# 4/4 [==============================] - 22s 6s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.3837 - val_accuracy: 0.9375
# Epoch 121/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9821
# Epoch 121: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 5s/step - loss: 0.0363 - accuracy: 0.9821 - val_loss: 0.3290 - val_accuracy: 0.9375
# Epoch 122/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 122: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4262 - val_accuracy: 0.7500
# Epoch 123/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 123: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 6s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.7283 - val_accuracy: 0.8125
# Epoch 124/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 1.0000
# Epoch 124: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.6601 - val_accuracy: 0.8125
# Epoch 125/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 125: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.4337 - val_accuracy: 0.7500
# Epoch 126/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 126: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4172 - val_accuracy: 0.9375
# Epoch 127/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 127: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.4419 - val_accuracy: 0.9375
# Epoch 128/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 0.9643
# Epoch 128: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.1297 - accuracy: 0.9643 - val_loss: 0.4359 - val_accuracy: 0.8750
# Epoch 129/200
# 4/4 [==============================] - ETA: 0s - loss: 4.1421e-04 - accuracy: 1.0000
# Epoch 129: val_loss did not improve from 0.13719
# 4/4 [==============================] - 23s 6s/step - loss: 4.1421e-04 - accuracy: 1.0000 - val_loss: 0.6389 - val_accuracy: 0.8750
# Epoch 130/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9643
# Epoch 130: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 5s/step - loss: 0.0511 - accuracy: 0.9643 - val_loss: 0.6425 - val_accuracy: 0.8750
# Epoch 131/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9821
# Epoch 131: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 6s/step - loss: 0.0166 - accuracy: 0.9821 - val_loss: 0.4155 - val_accuracy: 0.8750
# Epoch 132/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2056 - accuracy: 0.9531
# Epoch 132: val_loss did not improve from 0.13719
# 4/4 [==============================] - 22s 6s/step - loss: 0.2056 - accuracy: 0.9531 - val_loss: 0.2832 - val_accuracy: 0.8750
# Epoch 133/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 133: val_loss did not improve from 0.13719
# 4/4 [==============================] - 19s 6s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.7231 - val_accuracy: 0.8125
# Epoch 134/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 1.0000
# Epoch 134: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 5s/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 1.4818 - val_accuracy: 0.8125
# Epoch 135/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9464
# Epoch 135: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 5s/step - loss: 0.1995 - accuracy: 0.9464 - val_loss: 0.9453 - val_accuracy: 0.8750
# Epoch 136/200
# 4/4 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.8750
# Epoch 136: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 5s/step - loss: 0.3289 - accuracy: 0.8750 - val_loss: 0.5657 - val_accuracy: 0.6875
# Epoch 137/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2090 - accuracy: 0.9107
# Epoch 137: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.2090 - accuracy: 0.9107 - val_loss: 0.1655 - val_accuracy: 0.8750
# Epoch 138/200
# 4/4 [==============================] - ETA: 0s - loss: 0.6411 - accuracy: 0.9286
# Epoch 138: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.6411 - accuracy: 0.9286 - val_loss: 0.3179 - val_accuracy: 0.8125
# Epoch 139/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1256 - accuracy: 0.9464
# Epoch 139: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.1256 - accuracy: 0.9464 - val_loss: 2.3243 - val_accuracy: 0.7500
# Epoch 140/200
# 4/4 [==============================] - ETA: 0s - loss: 0.3616 - accuracy: 0.9107
# Epoch 140: val_loss did not improve from 0.13719
# 4/4 [==============================] - 20s 5s/step - loss: 0.3616 - accuracy: 0.9107 - val_loss: 0.7264 - val_accuracy: 0.7500
# Epoch 141/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 141: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 6s/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.3494 - val_accuracy: 0.8750
# Epoch 142/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 0.9464
# Epoch 142: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 6s/step - loss: 0.1961 - accuracy: 0.9464 - val_loss: 0.4089 - val_accuracy: 0.8125
# Epoch 143/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9821
# Epoch 143: val_loss did not improve from 0.13719
# 4/4 [==============================] - 21s 5s/step - loss: 0.0278 - accuracy: 0.9821 - val_loss: 0.3408 - val_accuracy: 0.8125
# Epoch 144/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0691 - accuracy: 0.9688
# Epoch 144: val_loss did not improve from 0.13719
# 4/4 [==============================] - 25s 7s/step - loss: 0.0691 - accuracy: 0.9688 - val_loss: 0.4345 - val_accuracy: 0.8125
# Epoch 145/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9821
# Epoch 145: val_loss did not improve from 0.13719
# 4/4 [==============================] - 19s 5s/step - loss: 0.1006 - accuracy: 0.9821 - val_loss: 0.6726 - val_accuracy: 0.7500
# Epoch 145: early stopping

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs_x = range(1, len(loss_values) + 1)
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.plot(epochs_x, loss_values, 'bo', label='Training loss')
plt.plot(epochs_x, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.legend()
plt.subplot(2,1,2)
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs_x, acc_values, 'bo', label='Training acc')
plt.plot(epochs_x, val_acc_values, 'b', label='Validation acc')
#plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
# Load the best saved model
model = load_model('model.h5')

# %%
#model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 96)   18432       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 64)   12288       ['average_pooling2d[0][0]']
#  batch_normalization_5 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 35, 35, 320)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 32)  96          ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 48)  144         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 32)  96          ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 32)  96          ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 64)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (CustomScal  (None, 35, 35, 320)  0          ['mixed_5b[0][0]',
#  eLayer)                                                          'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 32)  96          ['conv2d_21[0][0]']
#  ormalization)
#  activation_21 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 32)  96          ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 48)  144         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 32)  96          ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (CustomSc  (None, 35, 35, 320)  0          ['block35_1_ac[0][0]',
#  aleLayer)                                                        'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 32)  96          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 32)  96          ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 48)  144         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 32)  96          ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 35, 35, 32)  96          ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 35, 35, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (CustomSc  (None, 35, 35, 320)  0          ['block35_2_ac[0][0]',
#  aleLayer)                                                        'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 35, 35, 32)  96          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 35, 35, 32)  96          ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 35, 35, 48)  144         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 35, 35, 32)  96          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 35, 35, 32)  96          ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 35, 35, 64)  192         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (CustomSc  (None, 35, 35, 320)  0          ['block35_3_ac[0][0]',
#  aleLayer)                                                        'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 35, 35, 32)  96          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 35, 35, 32)  96          ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 35, 35, 48)  144         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 35, 35, 32)  96          ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 35, 35, 32)  96          ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 35, 35, 64)  192         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (CustomSc  (None, 35, 35, 320)  0          ['block35_4_ac[0][0]',
#  aleLayer)                                                        'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 35, 35, 32)  96          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 35, 35, 32)  96          ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 35, 35, 48)  144         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 35, 35, 32)  96          ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 35, 35, 32)  96          ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 35, 35, 64)  192         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_47[0][0]']
#  block35_6_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (CustomSc  (None, 35, 35, 320)  0          ['block35_5_ac[0][0]',
#  aleLayer)                                                        'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 35, 35, 32)  96          ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 35, 35, 32)  96          ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 35, 35, 48)  144         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_49[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 35, 35, 32)  96          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 35, 35, 32)  96          ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 35, 35, 64)  192         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_7_mixed[0][0]']
#
#  custom_scale_layer_6 (CustomSc  (None, 35, 35, 320)  0          ['block35_6_ac[0][0]',
#  aleLayer)                                                        'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_6[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 35, 35, 32)  96          ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_57[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_7_ac[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_57[0][0]']
# ...
#
#  activation_188 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_188[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_188[0][0]']
#
#  batch_normalization_189 (Batch  (None, 8, 8, 224)   672         ['conv2d_189[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_189[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_189[0][0]']
#
#  batch_normalization_187 (Batch  (None, 8, 8, 192)   576         ['conv2d_187[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 8, 8, 256)   768         ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_187[0][0]']
#
#  activation_190 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_190[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_187[0][0]',
#                                                                   'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_36 (CustomS  (None, 8, 8, 2080)  0           ['block8_6_ac[0][0]',
#  caleLayer)                                                       'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 8, 8, 2080)   0           ['custom_scale_layer_36[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (Batch  (None, 8, 8, 192)   576         ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 8, 8, 224)   672         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_193[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 8, 8, 192)   576         ['conv2d_191[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 8, 8, 256)   768         ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_194[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_37 (CustomS  (None, 8, 8, 2080)  0           ['block8_7_ac[0][0]',
#  caleLayer)                                                       'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 8, 8, 2080)   0           ['custom_scale_layer_37[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (Batch  (None, 8, 8, 192)   576         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_196[0][0]']
#
#  batch_normalization_197 (Batch  (None, 8, 8, 224)   672         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_197[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_197[0][0]']
#
#  batch_normalization_195 (Batch  (None, 8, 8, 192)   576         ['conv2d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 8, 8, 256)   768         ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_198[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_38 (CustomS  (None, 8, 8, 2080)  0           ['block8_8_ac[0][0]',
#  caleLayer)                                                       'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 8, 8, 2080)   0           ['custom_scale_layer_38[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (Batch  (None, 8, 8, 192)   576         ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 8, 8, 224)   672         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_201[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_201[0][0]']
#
#  batch_normalization_199 (Batch  (None, 8, 8, 192)   576         ['conv2d_199[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 8, 8, 256)   768         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_199[0][0]']
#
#  activation_202 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_202[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 8, 8, 448)    0           ['activation_199[0][0]',
#                                                                   'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 8, 8, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_39 (CustomS  (None, 8, 8, 2080)  0           ['block8_9_ac[0][0]',
#  caleLayer)                                                       'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 8, 8, 1536)   3194880     ['custom_scale_layer_39[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 8, 8, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 8, 8, 1536)   0           ['conv_7b_bn[0][0]']
#
#  flatten (Flatten)              (None, 98304)        0           ['conv_7b_ac[0][0]']
#
#  dense (Dense)                  (None, 100)          9830500     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 6)            606         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 64,167,842
# Trainable params: 9,831,106
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________

# %%
# Using the validation dataset
score = model.evaluate_generator(validation_generator)
print('Val loss:', score[0])
print('Val accuracy:', score[1])
# Out:
# C:\Users\Akshay P\AppData\Local\Temp\ipykernel_13292\1237713776.py:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(validation_generator)
# Val loss: 0.3209496736526489
# Val accuracy: 0.8333333134651184

# %%
# Using the test dataset
score = model.evaluate_generator(test_generator)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# C:\Users\Akshay P\AppData\Local\Temp\ipykernel_13292\4054959399.py:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(test_generator)
# Test loss: 0.32757848501205444
# Test accuracy: 0.8999999761581421

# %%
import itertools

#Plot the confusion matrix. Set Normalize = True/False
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Some reports
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

#Confution Matrix and Classification Report
Y_pred = model.predict_generator(test_generator)#, nb_test_samples // BATCH_SIZE, workers=1)
y_pred = np.argmax(Y_pred, axis=1)
target_names = classes

#Confution Matrix
cm = confusion_matrix(test_generator.classes, y_pred)
plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion Matrix')
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# C:\Users\Akshay P\AppData\Local\Temp\ipykernel_13292\845292353.py:6: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = model.predict_generator(test_generator)#, nb_test_samples // BATCH_SIZE, workers=1)
# Classification Report
#               precision    recall  f1-score   support
#
#         acai       1.00      0.80      0.89         5
#      cupuacu       1.00      1.00      1.00         5
#     graviola       1.00      1.00      1.00         5
#      guarana       0.80      0.80      0.80         5
#      pupunha       0.71      1.00      0.83         5
#       tucuma       1.00      0.80      0.89         5
#
#     accuracy                           0.90        30
#    macro avg       0.92      0.90      0.90        30
# weighted avg       0.92      0.90      0.90        30
